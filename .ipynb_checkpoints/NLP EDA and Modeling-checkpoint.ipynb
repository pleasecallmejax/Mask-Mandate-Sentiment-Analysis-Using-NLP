# %% [markdown]
# # Natural Language Processing and Modeling Notebook

# %% [markdown]
# ## First off let's import packages we plan to use

# %%
import re
import sys
import json
import nltk
import spacy
import string
import gensim
from tqdm import tqdm
import warnings
import imblearn
import requests
import twitter
import numpy as np
import xgboost as xgb
import pandas as pd
from scipy import stats 
import seaborn as sns
import texthero as hr
from PIL import Image 
from wordcloud import WordCloud
from nltk import pos_tag, FreqDist
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from sklearn.manifold import TSNE
from collections import defaultdict
from mpl_toolkits.mplot3d import Axes3D
from nltk.tokenize import TweetTokenizer
from sklearn.impute import SimpleImputer
from imblearn.over_sampling import SMOTE
from sklearn.dummy import DummyClassifier
from matplotlib.ticker import MaxNLocator
from nltk.corpus import stopwords, wordnet
from sklearn.feature_extraction import text
from sklearn.compose import ColumnTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline, make_pipeline
from imblearn.pipeline import Pipeline as imbPipeline
from nltk.stem import WordNetLemmatizer, PorterStemmer
from imblearn.metrics import classification_report_imbalanced
from nltk.tokenize import word_tokenize, regexp_tokenize, RegexpTokenizer
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold
from sklearn.ensemble import RandomForestClassifier, StackingClassifier, AdaBoostClassifier
from sklearn.metrics import plot_roc_curve, plot_confusion_matrix, confusion_matrix, classification_report, accuracy_score, precision_score
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ## We want to start by making the API calls necessary to aggregate the data we need and concatenate to a single dataframe.

# %%
#This call function allowed me to aggregate all the data I could from the Twitter API

def tweet_call(token):
    url = "https://api.twitter.com/2/tweets/search/recent?query=maskmandate&tweet.fields=geo,created_at,lang,possibly_sensitive,referenced_tweets,source&place.fields=country&max_results=100"

    payload={}
    headers = {
    'Authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAAA87TQEAAAAAshYtyDyl0fN52qZbLOLUku%2Fln%2Bg%3DUNzKuiAu5XmoNCCHtl0403jh2wepuXWQGWLKL8o8ZjnJodU8b6',
    'Cookie': 'guest_id=v1%3A163060937974157763; personalization_id="v1_fPNQ4agp422tRlmCgiVxHA=="'}

    response = requests.request("GET", url, headers=headers, data=payload)
    next_token = response.json()['meta']['next_token']
    #print(response.json)

# %% [markdown]
# ### This pair of for loops opens files, saves them as dataframes and then concatenates the results to a csv.

# %%
def aggregate_data(file):
    try:
        n = json.load(open(file))
        new_df = pd.DataFrame(n['data'])
        return new_df
    except:
        print(f'Error when reading "data" key) - please check file {file}')
        return

# %%
results_list = []

for file in range(1,62):
    results_list.append(aggregate_data(f't{file}.json'))
    
results_df = pd.concat(results_list, ignore_index=True)

# %%
def cleaner(csv_filepath):
    header_list = ['ID', 'Referenced Type', 'Tweet', 'Sensitive', 'Source','Date', 'Language']
    org_df = pd.read_csv(csv_filepath, index_col=0, names = header_list)
    org_df.reset_index(inplace = True, drop = True)
    return org_df

# %%
results_df.to_csv('tweets_df', mode='a', header=False)

# %% [markdown]
# ### Let's explore new datatypes, create other features, eliminate copies in our data and filter to only unique tweet values then fill nan values.

# %%
results_df['Created'] = pd.to_datetime(results_df['created_at'])
results_df.drop(columns=['created_at'], axis=1)
results_df = results_df.rename({'possibly_sensitive': 'Sensitive'}, axis=1)

# %%
results_df.text.duplicated().value_counts()
# Out:
# False    3127
# True     2378
# Name: text, dtype: int64

# %%
results_df.loc[results_df.text.duplicated(), :]
# Out:
#       Sensitive                created_at                   id  \
# 20        False  2021-09-09T09:35:14.000Z  1435899590113325056
# 21        False  2021-09-09T08:57:24.000Z  1435890069089312774
# 22        False  2021-09-09T08:55:25.000Z  1435889570155950081
# 33        False  2021-09-08T21:52:13.000Z  1435722670163775488
# 39        False  2021-09-08T18:29:44.000Z  1435671711538626560
# ...         ...                       ...                  ...
# 5500      False  2021-09-09T14:36:15.000Z  1435975344608227338
# 5501      False  2021-09-09T14:35:56.000Z  1435975261145686021
# 5502      False  2021-09-09T14:34:42.000Z  1435974951446761480
# 5503      False  2021-09-09T14:34:36.000Z  1435974929137111044
# 5504      False  2021-09-09T14:34:06.000Z  1435974802909679621
#
#                    source lang  \
# 20     Twitter for iPhone   en
# 21    Twitter for Android   en
# 22    Twitter for Android   en
# 33     Twitter for iPhone   en
# 39     Twitter for iPhone   en
# ...                   ...  ...
# 5500   Twitter for iPhone   en
# 5501      Twitter Web App   en
# 5502   Twitter for iPhone   en
# 5503      Twitter Web App   en
# 5504  Twitter for Android   en
#
#                                          referenced_tweets  \
# 20    [{'type': 'retweeted', 'id': '1433033391805538308'}]
# 21    [{'type': 'retweeted', 'id': '1433033391805538308'}]
# 22    [{'type': 'retweeted', 'id': '1433033391805538308'}]
# 33    [{'type': 'retweeted', 'id': '1435247630838288384'}]
# 39    [{'type': 'retweeted', 'id': '1435640216384049153'}]
# ...                                                    ...
# 5500                                                   NaN
# 5501  [{'type': 'retweeted', 'id': '1435934448776847361'}]
# 5502  [{'type': 'retweeted', 'id': '1435934448776847361'}]
# 5503  [{'type': 'retweeted', 'id': '1435964555176329220'}]
# 5504  [{'type': 'retweeted', 'id': '1435973076836098048'}]
#
#                                                                                                                                               text  \
# 20    RT @diecastryan: A classic ATL lineup. #delta #deltaairlines #airplane #aviation #avgeek #nikon #nikonphotography #atlanta #atlairport #tra…
# 21    RT @diecastryan: A classic ATL lineup. #delta #deltaairlines #airplane #aviation #avgeek #nikon #nikonphotography #atlanta #atlairport #tra…
# 22    RT @diecastryan: A classic ATL lineup. #delta #deltaairlines #airplane #aviation #avgeek #nikon #nikonphotography #atlanta #atlairport #tra…
# 33    RT @diecastryan: Who else is ready for fall?! #delta #deltaairlines #boston #fallcolors #boeing #aerialphotography #avgeek #airplane #aviat…
# 39     RT @omadnp: #DeltaAirlines - gate agent at #bna refused to enforce mask mandate in airport! Come on delta - you should be better than that!
# ...                                                                                                                                            ...
# 5500                                  I welcome a mask on a plane bc then no one can see me open mouth breath and drool on myself while I’m asleep
# 5501  RT @factsonlyplse: @Spicy_Heathen @davenewworld_2 They got a warning when they purchased tickets (mask policy) they got warnings when enter…
# 5502  RT @factsonlyplse: @Spicy_Heathen @davenewworld_2 They got a warning when they purchased tickets (mask policy) they got warnings when enter…
# 5503  RT @atima_omara: In case you were like me and thought the number of people acting a damn fool on the plane has been increasing? We were rig…
# 5504  RT @wendyc78757: @soledadobrien @MalcolmNance At this point, everybody knows the rules before boarding a plane. You don’t take your  mask o…
#
#       geo                   Created
# 20    NaN 2021-09-09 09:35:14+00:00
# 21    NaN 2021-09-09 08:57:24+00:00
# 22    NaN 2021-09-09 08:55:25+00:00
# 33    NaN 2021-09-08 21:52:13+00:00
# 39    NaN 2021-09-08 18:29:44+00:00
# ...   ...                       ...
# 5500  NaN 2021-09-09 14:36:15+00:00
# 5501  NaN 2021-09-09 14:35:56+00:00
# 5502  NaN 2021-09-09 14:34:42+00:00
# 5503  NaN 2021-09-09 14:34:36+00:00
# 5504  NaN 2021-09-09 14:34:06+00:00
#
# [2378 rows x 9 columns]

# %%
unique_df=results_df.drop_duplicates(subset='text', keep='first').copy()
unique_df=unique_df.fillna(0)

# %% [markdown]
# ### Lets use our remaining data to look at some visualing revolving the dates first.

# %%
new_df_idx=list(unique_df.source.value_counts(ascending=False)[:10].index)
new_df_idx
# Out:
# ['Twitter for iPhone',
#  'Twitter Web App',
#  'Twitter for Android',
#  'Raspberry Pi - ADS-B Receiver',
#  'Twitter for iPad',
#  'Twitter',
#  'PlaneFence-Belmont',
#  'TweetDeck',
#  'Hootsuite Inc.',
#  'dlvr.it']

# %%
unique_df['source'].value_counts(normalize=True, ascending=True, dropna=False).iloc[-10:].plot(kind='barh')
plt.title('Top Ten Tweet Sources')
plt.xlabel("Percentage of Tweets")
plt.ylabel("Sources", rotation=360);

# %%
## Converting non top 3 sources to placeholder Other because there are too many different sources
cond = [unique_df['source'] == 'Twitter for iPhone',
        unique_df['source'] == 'Twitter Web App',
        unique_df['source'] == 'Twitter for Android',
        unique_df['source'] == 'Raspberry Pi - ADS-B Receiver',
        unique_df['source'] == 'Twitter for iPad',
        unique_df['source'] == 'Twitter',
        unique_df['source'] == 'PlaneFence-Belmont']

choice = [unique_df['source'], unique_df['source'], unique_df['source'], unique_df['source'], unique_df['source'], unique_df['source'], unique_df['source']]

unique_df['source'] = np.select(cond, choice, 'Other')
unique_df['source'].value_counts(1, ascending=False)
# Out:
# 0       Twitter for iPhone
# 1       Twitter for iPhone
# 2       Twitter for iPhone
# 3       Twitter for iPhone
# 4                    Other
#                ...
# 5352       Twitter Web App
# 5353    Twitter for iPhone
# 5358      Twitter for iPad
# 5359       Twitter Web App
# 5361      Twitter for iPad
# Name: source, Length: 3127, dtype: object

# %%
fig,ax=plt.subplots()
unique_df['source'].value_counts(1, ascending=False).plot(kind='barh', figsize=(10,7), ax=ax)
ax.set_xticklabels(['0', '5%','10%', '15%', '20%', '25%', '30%', '35%', '40%'])
ax.set_title('Top Tweet Sources');

# %%
unique_df['source'].value_counts(1, ascending=False).plot.pie(figsize=(10,10), shadow=True, explode=(.1,0,0,0,0,0,0,0))
plt.ylabel("Sources of Tweets", loc='top', rotation=360);

# %% [markdown]
# ### Now lets' drop anything not in English and any tweets not sent by humens.

# %%
unique_df=unique_df.drop(unique_df['lang'].loc[unique_df['lang']!='en'].index)
unique_df=unique_df.drop(unique_df['source'].loc[unique_df['lang']=='Raspberry Pi - ADS-B Receiver'].index)

# %%
unique_df.loc[unique_df['geo']!= 0]
# Out:
#       Sensitive                created_at                   id  \
# 12        False  2021-09-09T13:31:38.000Z  1435959083434119172
# 17        False  2021-09-09T11:46:02.000Z  1435932505190903815
# 29        False  2021-09-09T03:41:01.000Z  1435810449929424899
# 40        False  2021-09-08T18:14:29.000Z  1435667876065824777
# 93        False  2021-09-08T00:06:08.000Z  1435393983304306693
# ...         ...                       ...                  ...
# 4640      False  2021-09-10T07:50:54.000Z  1436235720864141331
# 4855      False  2021-09-10T00:52:05.000Z  1436130323071320068
# 4969      False  2021-09-09T23:14:57.000Z  1436105877732290591
# 5105      False  2021-09-09T21:25:19.000Z  1436078286501826572
# 5161      False  2021-09-09T20:28:34.000Z  1436064005466968084
#
#                    source lang  \
# 12     Twitter for iPhone   en
# 17                  Other   en
# 29                  Other   en
# 40     Twitter for iPhone   en
# 93     Twitter for iPhone   en
# ...                   ...  ...
# 4640  Twitter for Android   en
# 4855  Twitter for Android   en
# 4969   Twitter for iPhone   en
# 5105   Twitter for iPhone   en
# 5161   Twitter for iPhone   en
#
#                                           referenced_tweets  \
# 12                                                        0
# 17                                                        0
# 29                                                        0
# 40        [{'type': 'quoted', 'id': '1435611385828884486'}]
# 93                                                        0
# ...                                                     ...
# 4640  [{'type': 'replied_to', 'id': '1436233810513956864'}]
# 4855  [{'type': 'replied_to', 'id': '1436102504979197954'}]
# 4969  [{'type': 'replied_to', 'id': '1436092049623863301'}]
# 5105                                                      0
# 5161                                                      0
#
#                                                                                                                                                                                                          text  \
# 12    A throwback to only last year, but it feels like an eternity ago. \n\nLast flight into Las Vegas in March 2020.  Next flight into Las Vegas - this Sunday, for a trade show.\n#throwbackthursday #bu...
# 17                                         Columbus here we come!   GO DUCKS!!! #oregonohiostate #cfb #ncaa #travel #goducks #flyhigh #deltaairlines @ Portland International Airport https://t.co/qfk1Jy0g9r
# 29                                            @detroitwick @tripwipes #tripmitt got us covered! Thanks @a__smith for the hookup. #deltaairlines #laguardiaairport @ LaGuardia Airport https://t.co/gCiTYjxRFj
# 40                                                                                                                           Whichever will provide more award travel. #DeltaAirlines https://t.co/fb2jvhvDn9
# 93    Hey @Delta typically love u guys but wtf kinda UPGRADE is this? Literally sitting IN THE AISLE. Most uncomfortable flight of my life. Would rather churn butter w/a colonial woman on the wing. #del...
# ...                                                                                                                                                                                                       ...
# 4640  @LesaRenee333 @POTUS Thank you Mr. President! They should also face lifetime travel bans. There is no excuse for this behavior. I don't like wearing masks just as much as they do, but I am not abo...
# 4855  @bryanbehar I drove down with my second twin daughter to move her into her dorm 2 weeks ago then flew home. Thank God the plane was almost empty and no one else in my row as I cried the whole way ...
# 4969                                                                                                                                      @POTUS They shouldn’t let them on the plane if they refuse to mask!
# 5105          #Breaking @POTUS announces @TSA will double the fines for people who refuse to wear a mask on a plane. @POTUS also tells those people to have some respect to ✈️ staff. https://t.co/YsQaejGVY6
# 5161  I’m on an #Amtrak train to San Diego but they are stopping it right now to kick someone off for refusing to wear a mask. Unlike a plane, they can just boot you off wherever. #cityofcommerce https:...
#
#                                                                                                                   geo  \
# 12                                                                                   {'place_id': '7142eb97ae21e839'}
# 17    {'place_id': 'ac88a4f17a51c7fc', 'coordinates': {'type': 'Point', 'coordinates': [-122.59622222, 45.58886979]}}
# 29     {'place_id': '00c39537733fa112', 'coordinates': {'type': 'Point', 'coordinates': [-73.87288343, 40.77195338]}}
# 40                                                                                   {'place_id': '019e0ca71523f3f0'}
# 93                                                                                   {'place_id': '0fc7e0a406d55000'}
# ...                                                                                                               ...
# 4640                                                                                 {'place_id': '5c2b5e46ab891f07'}
# 4855                                                                                 {'place_id': 'cf574ccb037d4ff3'}
# 4969                                                                                 {'place_id': '9807c5c5f7a2c6ce'}
# 5105                                                                                 {'place_id': '00ab941b685334e3'}
# 5161                                                                                 {'place_id': 'be347aa731d4353b'}
#
#                        Created
# 12   2021-09-09 13:31:38+00:00
# 17   2021-09-09 11:46:02+00:00
# 29   2021-09-09 03:41:01+00:00
# 40   2021-09-08 18:14:29+00:00
# 93   2021-09-08 00:06:08+00:00
# ...                        ...
# 4640 2021-09-10 07:50:54+00:00
# 4855 2021-09-10 00:52:05+00:00
# 4969 2021-09-09 23:14:57+00:00
# 5105 2021-09-09 21:25:19+00:00
# 5161 2021-09-09 20:28:34+00:00
#
# [67 rows x 9 columns]

# %% [markdown]
# ### Doesn't seem that geo is all that helpful but since we have filtered on englidh tweets and removed the Raspberry Pi automated tweets now we can shed those columns and begin preprocessing.

# %%
clean_df=unique_df.drop(columns=['Created', 'created_at','id','Sensitive','geo','lang','referenced_tweets','source'], axis=1)
clean_df
# Out:
#                                                                                                                                                                                                          text
# 0                                                                 RT @omadnp: #DeltaAirlines - gate agent at #bna refused to enforce mask mandate in airport! Come on delta - you should be better than that!
# 1     Very interesting choice of words from pilot from @Delta airlines pilot from BOS to DTW: “thank you for using your CHOICE of wearing a mask on our flight.” Isn’t it law to wear a mask???? I’d like ...
# 2                                                                             #DeltaAirlines - gate agent at #bna refused to enforce mask mandate in airport! Come on delta - you should be better than that!
# 3                       He had a trump 2024 mask and full trump 2024 gear. He was a nice guy and wasn’t hostile or anything yet #deltaairlines liberal flight attendant had him removed #Delta I hope he sues
# 4     U.S. airlines cut Q3 guidance as COVID cases surge again.\n#UnitedAirlines #DeltaAirlines #AmericanAirlines #StockMarketNews #Coronavirus #EdBastian #DeltaVariant\nhttps://t.co/SjAEUp0iZY https://...
# ...                                                                                                                                                                                                       ...
# 5352  @SudiptaMallik16 @davenewworld_2 Did you see his rant, without a mask, and his travelling companion pulling her mask down to try and justify this to the rest of the plan?\n\nYes, there is lots to ...
# 5353              @mmpadellan I’m so sick of these assholes. I spend 12-13 hrs/day in a mask while I’m working, a few hours on a plane won’t kill you, although refusing to wear one might kill someone else.
# 5358                                                                                                   @freepeeper I really don’t understand they get in the plane knowing they need to wear their mask 🤷🏾‍♀️
# 5359  Good! @UnitedAirlines_ Needs to improve their procedures. On a flight across country, they didn't make sure people had on #masks , their pilot in the terminal with improperly fitting mask, and pla...
# 5361  @factsonlyplse @Spicy_Heathen @davenewworld_2 YUP\nEvery US airport has mask mandate announcement playing on a loop…  “Federal law requires that masks be worn properly at all times in the airport,...
#
# [2817 rows x 1 columns]

# %%
#Function to clean tweet text
def clean_tweet(tweet):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    regrex_pattern.sub(r'',tweet)
    #remove links
    tweet_http= re.sub(r"http\S+", '', tweet)
    # remove RTs
    tweet_rt = re.sub(r'RT[\s]+', '', tweet_http) 
    # remove [VIDEO] text
    tweet_v = re.sub(r'\[VIDEO\]', '', tweet_rt) 
    # remove {link} text
    tweet_l = re.sub(r'\{link\}', '', tweet_v) 
    # remove numbers                           re.sub(pattern, repl, string, count=0, flags=0)
    tweet_nonum = re.sub(r'\d+', '', tweet_l)
    # remove punctuations and lower case
    tweet_nopunct = ''.join([char.lower() for char in tweet_nonum if char not in string.punctuation])
    # substitute multiple whitespace with single whitespace
    cleaned_tweet = re.sub('\s+',' ', tweet_nopunct).strip()
    return cleaned_tweet

# %%
#Function to initialize the word tags for lemmatizing
def get_wordnet_pos(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

#Tokenizing and lemmatizing
def lema(tweet):
    lem = WordNetLemmatizer()
    tt = TweetTokenizer(strip_handles=True)
    cusstopwords = text.ENGLISH_STOP_WORDS.union(['link', 'climate', 'change', 'global','warm', 'warming'])
    lem_tweet = ' '.join([lem.lemmatize(w, get_wordnet_pos(w)) for w in tt.tokenize(tweet)if w not in cusstopwords])
    return lem_tweet

# %%
def stem(tweet):
    stemmer = PorterStemmer()
    tt = TweetTokenizer(strip_handles=True)
    cusstopwords = text.ENGLISH_STOP_WORDS.union(['link', 'climate', 'change', 'global','warm', 'warming'])
    tweets_stem = ' '.join([stemmer.stem(w) for w in tt.tokenize(tweet)if w not in cusstopwords])        
    return tweets_stem

def remove_emojis(tweet):
    emoj = re.compile("["
        u"\U0001F600-\U0001F64F"  
        u"\U0001F300-\U0001F5FF"
        u"\U0001F680-\U0001F6FF" 
        u"\U0001F1E0-\U0001F1FF"  
        u"\U00002500-\U00002BEF"  
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoj, '', tweet)

# %%
clean_df['clean_tweets'] = [clean_tweet(i) for i in clean_df['text']]
clean_df['clean_tweets'] = [remove_emojis(i) for i in clean_df['text']]
clean_df['lemmed_tweets'] = [lema(i) for i in clean_df['clean_tweets']]
clean_df['stemmed_tweets'] = [stem(i) for i in clean_df['clean_tweets']]

# %%
clean_df
# Out:
#                                                                                                                                                                                                          text  \
# 0                                                                 RT @omadnp: #DeltaAirlines - gate agent at #bna refused to enforce mask mandate in airport! Come on delta - you should be better than that!
# 1     Very interesting choice of words from pilot from @Delta airlines pilot from BOS to DTW: “thank you for using your CHOICE of wearing a mask on our flight.” Isn’t it law to wear a mask???? I’d like ...
# 2                                                                             #DeltaAirlines - gate agent at #bna refused to enforce mask mandate in airport! Come on delta - you should be better than that!
# 3                       He had a trump 2024 mask and full trump 2024 gear. He was a nice guy and wasn’t hostile or anything yet #deltaairlines liberal flight attendant had him removed #Delta I hope he sues
# 4     U.S. airlines cut Q3 guidance as COVID cases surge again.\n#UnitedAirlines #DeltaAirlines #AmericanAirlines #StockMarketNews #Coronavirus #EdBastian #DeltaVariant\nhttps://t.co/SjAEUp0iZY https://...
# ...                                                                                                                                                                                                       ...
# 5352  @SudiptaMallik16 @davenewworld_2 Did you see his rant, without a mask, and his travelling companion pulling her mask down to try and justify this to the rest of the plan?\n\nYes, there is lots to ...
# 5353              @mmpadellan I’m so sick of these assholes. I spend 12-13 hrs/day in a mask while I’m working, a few hours on a plane won’t kill you, although refusing to wear one might kill someone else.
# 5358                                                                                                   @freepeeper I really don’t understand they get in the plane knowing they need to wear their mask 🤷🏾‍♀️
# 5359  Good! @UnitedAirlines_ Needs to improve their procedures. On a flight across country, they didn't make sure people had on #masks , their pilot in the terminal with improperly fitting mask, and pla...
# 5361  @factsonlyplse @Spicy_Heathen @davenewworld_2 YUP\nEvery US airport has mask mandate announcement playing on a loop…  “Federal law requires that masks be worn properly at all times in the airport,...
#
#                                                                                                                                                                                                  clean_tweets  \
# 0                                                                 RT @omadnp: #DeltaAirlines - gate agent at #bna refused to enforce mask mandate in airport! Come on delta - you should be better than that!
# 1     Very interesting choice of words from pilot from @Delta airlines pilot from BOS to DTW: “thank you for using your CHOICE of wearing a mask on our flight.” Isn’t it law to wear a mask???? I’d like ...
# 2                                                                             #DeltaAirlines - gate agent at #bna refused to enforce mask mandate in airport! Come on delta - you should be better than that!
# 3                       He had a trump 2024 mask and full trump 2024 gear. He was a nice guy and wasn’t hostile or anything yet #deltaairlines liberal flight attendant had him removed #Delta I hope he sues
# 4     U.S. airlines cut Q3 guidance as COVID cases surge again.\n#UnitedAirlines #DeltaAirlines #AmericanAirlines #StockMarketNews #Coronavirus #EdBastian #DeltaVariant\nhttps://t.co/SjAEUp0iZY https://...
# ...                                                                                                                                                                                                       ...
# 5352  @SudiptaMallik16 @davenewworld_2 Did you see his rant, without a mask, and his travelling companion pulling her mask down to try and justify this to the rest of the plan?\n\nYes, there is lots to ...
# 5353              @mmpadellan I’m so sick of these assholes. I spend 12-13 hrs/day in a mask while I’m working, a few hours on a plane won’t kill you, although refusing to wear one might kill someone else.
# 5358                                                                                                        @freepeeper I really don’t understand they get in the plane knowing they need to wear their mask
# 5359  Good! @UnitedAirlines_ Needs to improve their procedures. On a flight across country, they didn't make sure people had on #masks , their pilot in the terminal with improperly fitting mask, and pla...
# 5361  @factsonlyplse @Spicy_Heathen @davenewworld_2 YUP\nEvery US airport has mask mandate announcement playing on a loop…  “Federal law requires that masks be worn properly at all times in the airport,...
#
#                                                                                                                                                                                                 lemmed_tweets  \
# 0                                                                                                             RT : #DeltaAirlines - gate agent #bna refuse enforce mask mandate airport ! Come delta - well !
# 1                                            Very interest choice word pilot airline pilot BOS DTW : “ thank use CHOICE wear mask flight . ” Isn ’ t law wear mask ? ? ? I ’ d like response #DeltaAirlines .
# 2                                                                                                                  #DeltaAirlines - gate agent #bna refuse enforce mask mandate airport ! Come delta - well !
# 3                                                                          He trump 2024 mask trump 2024 gear . He nice guy wasn ’ t hostile #deltaairlines liberal flight attendant remove #Delta I hope sue
# 4     U . S . airline cut Q3 guidance COVID case surge . #UnitedAirlines #DeltaAirlines #AmericanAirlines #StockMarketNews #Coronavirus #EdBastian #DeltaVariant https://t.co/SjAEUp0iZY https://t.co/Qrbi...
# ...                                                                                                                                                                                                       ...
# 5352                                                                      Did rant , mask , travel companion pull mask try justify rest plan ? Yes , lot unpack , like rest passenger didn't throw plane trip
# 5353                                                                                               I ’ m sick asshole . I spend 12-13 hr / day mask I ’ m work , hour plane won ’ t kill , refuse wear kill .
# 5358                                                                                                                                                    I really don ’ t understand plane know need wear mask
# 5359                             Good ! Needs improve procedure . On flight country , didn't make sure people #masks , pilot terminal improperly fitting mask , plane packed people . https://t.co/bGwpRpqIVO
# 5361            YUP Every US airport mask mandate announcement play loop … “ Federal law require mask worn properly time airport , jetway plane ” . The gate attendant announce flight attendant tell board .
#
#                                                                                                                                                                                     stemmed_tweets
# 0                                                                                                     RT : #deltaairlin - gate agent #bna refus enforc mask mandat airport ! come delta - better !
# 1                                        veri interest choic word pilot airlin pilot bo dtw : “ thank use choic wear mask flight . ” isn ’ t law wear mask ? ? ? I ’ d like respons #deltaairlin .
# 2                                                                                                          #deltaairlin - gate agent #bna refus enforc mask mandat airport ! come delta - better !
# 3                                                                        He trump 2024 mask trump 2024 gear . He nice guy wasn ’ t hostil #deltaairlin liber flight attend remov #delta I hope sue
# 4     U . S . airlin cut Q3 guidanc covid case surg . #unitedairlin #deltaairlin #americanairlin #stockmarketnew #coronaviru #edbastian #deltavari https://t.co/sjaeup0izi https://t.co/qrbitxhfmp
# ...                                                                                                                                                                                            ...
# 5352                                                              did rant , mask , travel companion pull mask tri justifi rest plan ? ye , lot unpack , like rest passeng didn't throw plane trip
# 5353                                                                                      I ’ m sick asshol . I spend 12-13 hr / day mask I ’ m work , hour plane won ’ t kill , refus wear kill .
# 5358                                                                                                                                         I realli don ’ t understand plane know need wear mask
# 5359                                good ! need improv procedur . On flight countri , didn't make sure peopl #mask , pilot termin improperli fit mask , plane pack peopl . https://t.co/bgwprpqivo
# 5361                 yup everi US airport mask mandat announc play loop … “ feder law requir mask worn properli time airport , jetway plane ” . the gate attend announc flight attend tell board .
#
# [2817 rows x 4 columns]

# %%
#Running through an API for sentiment analysis
url = "https://text-analysis12.p.rapidapi.com/sentiment-analysis/api/v1.1"

payload = "{\"language\": \"english\", \"text\": \"I want less taxes.\"}"

headers = {
    'content-type': "application/json",
    'x-rapidapi-host': "text-analysis12.p.rapidapi.com",
    'x-rapidapi-key': "f8d244aeb1msha67e6edebf2951dp1304d6jsn215788b5fa29"
    }

response = requests.request("POST", url, data=payload, headers=headers).json()

print(response)
# Out:
# {'time_taken': 0.006326913833618164, 'msg': 'Sentiment Analysis successful', 'ok': True, 'aggregate_sentiment': {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.0772}, 'sentiment_list': [{'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.0772, 'sentence': 'I want less taxes.'}], 'sentiment': 'positive'}

# %%
#Running through an API for sentiment analysis
def sent(tweet):

    url = "https://text-analysis12.p.rapidapi.com/sentiment-analysis/api/v1.1"

    payload = '{\\"language\\": \\"english\\", \\"text\\": ' + f'\\{tweet}}'

    headers = {
        'content-type': "application/json",
        'x-rapidapi-host': "text-analysis12.p.rapidapi.com",
        'x-rapidapi-key': "f8d244aeb1msha67e6edebf2951dp1304d6jsn215788b5fa29"
    }

    response = requests.request("POST", url, data=payload, headers=headers).json()

    print(response)
# Out:
#   File "<ipython-input-57-7e1450ca1dfa>", line 6
#     payload = "{\'language\': \'english\', \'text\': \\" + f'{tweet}\}'
#                                                            ^
# SyntaxError: f-string: single '}' is not allowed

# %%
new_stopwords = []
punctuations = string.punctuation
stopwords.extend(new_stopwords)
stopwords.extend(punctuations)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-3ce439285ccf> in <module>
#       1 new_stopwords = []
#       2 punctuations = string.punctuation
# ----> 3 stopwords.extend(new_stopwords)
#       4 stopwords.extend(punctuations)
#
# AttributeError: 'WordListCorpusReader' object has no attribute 'extend'

# %%
tweet = "I want less taxes."
sent(tweet)
# Out:
# {'time_taken': 0.0007658004760742188, 'msg': 'validation error, incorrect data passed to the server', 'ok': False}
