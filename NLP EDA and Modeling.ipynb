# %% [markdown]
# # Natural Language Processing and Modeling Notebook

# %% [markdown]
# ## First off let's import packages we plan to use

# %%
import re
import sys
import json
import spacy
import string
import gensim
from tqdm import tqdm
import warnings
import imblearn
import requests
import twitter
import numpy as np
import xgboost as xgb
import pandas as pd
from scipy import stats 
import seaborn as sns
import texthero as hr
from PIL import Image 
from wordcloud import WordCloud
from nltk import pos_tag, FreqDist
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from sklearn.manifold import TSNE
from collections import defaultdict
from mpl_toolkits.mplot3d import Axes3D
from nltk.tokenize import TweetTokenizer
from sklearn.impute import SimpleImputer
from imblearn.over_sampling import SMOTE
from sklearn.dummy import DummyClassifier
from matplotlib.ticker import MaxNLocator
from nltk.corpus import stopwords, wordnet
from sklearn.feature_extraction import text
from sklearn.compose import ColumnTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline, make_pipeline
from imblearn.pipeline import Pipeline as imbPipeline
from nltk.stem import WordNetLemmatizer, PorterStemmer
from imblearn.metrics import classification_report_imbalanced
from nltk.tokenize import word_tokenize, regexp_tokenize, RegexpTokenizer
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold
from sklearn.ensemble import RandomForestClassifier, StackingClassifier, AdaBoostClassifier
from sklearn.metrics import plot_roc_curve, plot_confusion_matrix, confusion_matrix, classification_report, accuracy_score, precision_score
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ## We want to start by making the API calls necessary to aggregate the data we need and concatenate to a single dataframe.

# %%
#This call function allowed me to aggregate all the data I could from the Twitter API

def tweet_call(token):
    url = "https://api.twitter.com/2/tweets/search/recent?query=maskmandate&tweet.fields=geo,created_at,lang,possibly_sensitive,referenced_tweets,source&place.fields=country&max_results=100"

    payload={}
    headers = {
    'Authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAAA87TQEAAAAAshYtyDyl0fN52qZbLOLUku%2Fln%2Bg%3DUNzKuiAu5XmoNCCHtl0403jh2wepuXWQGWLKL8o8ZjnJodU8b6',
    'Cookie': 'guest_id=v1%3A163060937974157763; personalization_id="v1_fPNQ4agp422tRlmCgiVxHA=="'}

    response = requests.request("GET", url, headers=headers, data=payload)
    next_token = response.json()['meta']['next_token']
    #print(response.json)

# %% [markdown]
# ### This pair of for loops opens files, saves them as dataframs and then concatenates the results to a csv.

# %%
def aggregate_data(file):
    data = json.load(open(file))
    new_df = pd.DataFrame(data['data'])
    return new_df

# %%
results_list = []

for file in range(1,48):
    results_list.append(aggregate_data(f't{file}.json'))
    
results_df = pd.concat(results_list, ignore_index=True)

# %%
def cleaner(csv_filepath):
    header_list = ['ID', 'Referenced Type', 'Tweet', 'Sensitive', 'Source','Date', 'Language']
    org_df = pd.read_csv(csv_filepath, index_col=0, names = header_list)
    org_df.reset_index(inplace = True, drop = True)
    return org_df

# %%
results_df.to_csv('tweets_df', mode='a', header=False)

# %% [markdown]
# ### Let's explore new datatypes, create other features, eliminate copies in our data and filter to only unique tweet values.

# %%
results_df['Created'] = pd.to_datetime(results_df['created_at'])
results.columns()

# %%
results_df.text.duplicated().value_counts()
# Out:
# False    2587
# True     1599
# Name: text, dtype: int64

# %%
results_df.loc[results_df.text.duplicated(), :]
# Out:
#       possibly_sensitive                created_at                   id  \
# 20                 False  2021-09-09T09:35:14.000Z  1435899590113325056
# 21                 False  2021-09-09T08:57:24.000Z  1435890069089312774
# 22                 False  2021-09-09T08:55:25.000Z  1435889570155950081
# 33                 False  2021-09-08T21:52:13.000Z  1435722670163775488
# 39                 False  2021-09-08T18:29:44.000Z  1435671711538626560
# ...                  ...                       ...                  ...
# 4170               False  2021-09-02T19:44:06.000Z  1433516099786661892
# 4175               False  2021-09-02T19:31:19.000Z  1433512882642292738
# 4178               False  2021-09-02T19:10:14.000Z  1433507576889544717
# 4181               False  2021-09-02T18:51:41.000Z  1433502907601588234
# 4185               False  2021-09-02T18:44:53.000Z  1433501199928541190
#
#                    source lang  \
# 20     Twitter for iPhone   en
# 21    Twitter for Android   en
# 22    Twitter for Android   en
# 33     Twitter for iPhone   en
# 39     Twitter for iPhone   en
# ...                   ...  ...
# 4170  Twitter for Android   en
# 4175      Twitter Web App   en
# 4178   Twitter for iPhone   en
# 4181  Twitter for Android   en
# 4185   Twitter for iPhone   en
#
#                                          referenced_tweets  \
# 20    [{'type': 'retweeted', 'id': '1433033391805538308'}]
# 21    [{'type': 'retweeted', 'id': '1433033391805538308'}]
# 22    [{'type': 'retweeted', 'id': '1433033391805538308'}]
# 33    [{'type': 'retweeted', 'id': '1435247630838288384'}]
# 39    [{'type': 'retweeted', 'id': '1435640216384049153'}]
# ...                                                    ...
# 4170  [{'type': 'retweeted', 'id': '1433268482527809536'}]
# 4175  [{'type': 'retweeted', 'id': '1433345572405186562'}]
# 4178  [{'type': 'retweeted', 'id': '1433268482527809536'}]
# 4181  [{'type': 'retweeted', 'id': '1433268482527809536'}]
# 4185  [{'type': 'retweeted', 'id': '1433497234147000325'}]
#
#                                                                                                                                                   text  \
# 20        RT @diecastryan: A classic ATL lineup. #delta #deltaairlines #airplane #aviation #avgeek #nikon #nikonphotography #atlanta #atlairport #tra…
# 21        RT @diecastryan: A classic ATL lineup. #delta #deltaairlines #airplane #aviation #avgeek #nikon #nikonphotography #atlanta #atlairport #tra…
# 22        RT @diecastryan: A classic ATL lineup. #delta #deltaairlines #airplane #aviation #avgeek #nikon #nikonphotography #atlanta #atlairport #tra…
# 33        RT @diecastryan: Who else is ready for fall?! #delta #deltaairlines #boston #fallcolors #boeing #aerialphotography #avgeek #airplane #aviat…
# 39         RT @omadnp: #DeltaAirlines - gate agent at #bna refused to enforce mask mandate in airport! Come on delta - you should be better than that!
# ...                                                                                                                                                ...
# 4170  RT @theoztrucker: I was on a plane yesterday. \n\nMask all the way and social distance through the terminal.\n\nSit side by side on a packed pl…
# 4175      RT @ShentonStage: First time on a plane since 2019! @VirginAtlantic announce that mask wearing on the flight is MANDATORY as a condition of…
# 4178  RT @theoztrucker: I was on a plane yesterday. \n\nMask all the way and social distance through the terminal.\n\nSit side by side on a packed pl…
# 4181  RT @theoztrucker: I was on a plane yesterday. \n\nMask all the way and social distance through the terminal.\n\nSit side by side on a packed pl…
# 4185  RT @BlogThatFailed: When you’re listening to the new @Mastiffhchc on a plane &amp; it disconnects from the headphones …  I’ve just shared the j…
#
#       geo                   Created
# 20    NaN 2021-09-09 09:35:14+00:00
# 21    NaN 2021-09-09 08:57:24+00:00
# 22    NaN 2021-09-09 08:55:25+00:00
# 33    NaN 2021-09-08 21:52:13+00:00
# 39    NaN 2021-09-08 18:29:44+00:00
# ...   ...                       ...
# 4170  NaN 2021-09-02 19:44:06+00:00
# 4175  NaN 2021-09-02 19:31:19+00:00
# 4178  NaN 2021-09-02 19:10:14+00:00
# 4181  NaN 2021-09-02 18:51:41+00:00
# 4185  NaN 2021-09-02 18:44:53+00:00
#
# [1599 rows x 9 columns]

# %%
unique_df=results_df.drop_duplicates(subset='text', keep='first').copy()

# %%
unique_df.source.value_counts()
# Out:
# Twitter for iPhone               917
# Twitter Web App                  620
# Twitter for Android              486
# Raspberry Pi - ADS-B Receiver    170
# Twitter for iPad                  75
#                                 ...
# Quant Data (Production)            1
# B9                                 1
# SNAP101                            1
# The Domain Bot                     1
# mrproverbe                         1
# Name: source, Length: 90, dtype: int64

# %%
unique_df=unique_df.fillna(0)

# %%
unique_df=unique_df.drop(unique_df['lang'].loc[unique_df['lang']!='en'].index)
unique_df=unique_df.drop(unique_df['source'].loc[unique_df['lang']=='Raspberry Pi - ADS-B Receiver'].index)

# %%
unique_df.loc[unique_df['geo']!= 0]
# Out:
#       possibly_sensitive                created_at                   id  \
# 12                 False  2021-09-09T13:31:38.000Z  1435959083434119172
# 17                 False  2021-09-09T11:46:02.000Z  1435932505190903815
# 29                 False  2021-09-09T03:41:01.000Z  1435810449929424899
# 40                 False  2021-09-08T18:14:29.000Z  1435667876065824777
# 93                 False  2021-09-08T00:06:08.000Z  1435393983304306693
# 127                False  2021-09-07T16:35:57.000Z  1435280689059008513
# 191                False  2021-09-06T19:48:14.000Z  1434966694418653188
# 201                False  2021-09-06T17:19:07.000Z  1434929163937271808
# 203                False  2021-09-06T16:22:24.000Z  1434914893216485376
# 211                False  2021-09-06T01:55:57.000Z  1434696844928438278
# 212                False  2021-09-05T23:36:10.000Z  1434661663773532162
# 221                False  2021-09-05T18:57:42.000Z  1434591587107889152
# 270                False  2021-09-04T18:16:31.000Z  1434218835880644613
# 286                False  2021-09-04T15:30:07.000Z  1434176960050212874
# 291                False  2021-09-04T12:19:21.000Z  1434128953401389057
# 296                False  2021-09-04T10:39:57.000Z  1434103938593218560
# 373                False  2021-09-03T05:25:28.000Z  1433662406253682693
# 458                False  2021-09-09T13:53:05.000Z  1435964479733387266
# 718                False  2021-09-07T15:01:13.000Z  1435256851420041226
# 881                False  2021-09-09T16:00:51.000Z  1435996632970153994
# 959                False  2021-09-06T20:21:15.000Z  1434975002814816261
# 1140               False  2021-09-05T22:57:33.000Z  1434651946103685124
# 1460               False  2021-09-03T20:16:56.000Z  1433886751366471681
# 1600               False  2021-09-03T14:05:11.000Z  1433793197508079621
# 1727               False  2021-09-03T15:16:56.000Z  1433811252917198853
# 3225   Twitter for iPhone   en
# 3236   Twitter for iPhone   en
# 3262   Twitter for iPhone   en
# 3322   Twitter for iPhone   en
# 3425   Twitter for iPhone   en
# 3479   Twitter for iPhone   en
# 3510   Twitter for iPhone   en
# 3556   Twitter for iPhone   en
# 3597  Twitter for Android   en
# 3645   Twitter for iPhone   en
# 3658  Twitter for Android   en
# 3850   Twitter for iPhone   en
# 3854   Twitter for iPhone   en
# 3919   Twitter for iPhone   en
# 4010   Twitter for iPhone   en
# 4011   Twitter for iPhone   en
# 4015   Twitter for iPhone   en
# 4072   Twitter for iPhone   en
#
#                                           referenced_tweets  \
# 12                                                        0
# 17                                                        0
# 29                                                        0
# 40        [{'type': 'quoted', 'id': '1435611385828884486'}]
# 93                                                        0
# 127   [{'type': 'replied_to', 'id': '1435278998318170114'}]
# 191                                                       0
# 201   [{'type': 'replied_to', 'id': '1434927041363824645'}]
# 203                                                       0
# 211                                                       0
# 212                                                       0
# 221                                                       0
# 270                                                       0
# 286                                                       0
# 291                                                       0
# 296                                                       0
# 373                                                       0
# 458       [{'type': 'quoted', 'id': '1435946387678564355'}]
# 718   [{'type': 'replied_to', 'id': '1434889159399911425'}]
# 881       [{'type': 'quoted', 'id': '1435930740143841280'}]
# 959   [{'type': 'replied_to', 'id': '1434971421952851968'}]
# 1140                                                      0
# 1460      [{'type': 'quoted', 'id': '1433432728129589268'}]
# 1600  [{'type': 'replied_to', 'id': '1433788008436625410'}]
# 1727  [{'type': 'replied_to', 'id': '1433547687358607363'}]
# 1789                                                      0
# 1920                                                      0
# 2012  [{'type': 'replied_to', 'id': '1433497756333711365'}]
# 2297      [{'type': 'quoted', 'id': '1435955400067751938'}]
# 2361  [{'type': 'replied_to', 'id': '1435947359679225857'}]
# 2446                                                      0
# 2510  [{'type': 'replied_to', 'id': '1435832536878305284'}]
# 2641                                                      0
# 2750  [{'type': 'replied_to', 'id': '1435617807199358985'}]
# 2950  [{'type': 'replied_to', 'id': '1435629409373937673'}]
# 3063  [{'type': 'replied_to', 'id': '1435573645535969289'}]
# 3095  [{'type': 'replied_to', 'id': '1435483971572289546'}]
# 3225                                                      0
# 3236  [{'type': 'replied_to', 'id': '1434884739748536322'}]
# 3262                                                      0
# 3322                                                      0
# 3425                                                      0
# 3479  [{'type': 'replied_to', 'id': '1434486176723914753'}]
# 3510  [{'type': 'replied_to', 'id': '1434616859127697408'}]
# 3556                                                      0
# 3597                                                      0
# 3645                                                      0
# 3658                                                      0
# 3850  [{'type': 'replied_to', 'id': '1434147596189192192'}]
# 3854  [{'type': 'replied_to', 'id': '1434148536376045568'}]
# 3919                                                      0
# 4010  [{'type': 'replied_to', 'id': '1433821688920162305'}]
# 4011                                                      0
# 4015                                                      0
# 4072                                                      0
#
#                                                                                                                                                                                                          text  \
# 12    A throwback to only last year, but it feels like an eternity ago. \n\nLast flight into Las Vegas in March 2020.  Next flight into Las Vegas - this Sunday, for a trade show.\n#throwbackthursday #bu...
# 3322                                                                                                       the guy next to me on the plane was barefoot, didn’t wear deodorant, and barely had a mask on 🤢🤮🤮😭
# 3425                                                                                                                                                    Snack time on the plane! Everyone take your mask off!
# 3479                                                                                  @McKaylaRoseJ Meanwhile on this plane &amp; they've announced about 18x pre-flight to make sure you have your mask on 🙄
# 3510          @AlloMumphrey There is a reason they tell you to put your face mask on yourself first when you are in a plane, you can’t help anyone if you aren’t helping yourself. Rest, relax, take a break.
# 3556  @Ryanair @askryanair just completed return flight to ibiza. Plane really dirty on outbound flight and mask wearing not enforced on either journey. Particularly bad on way home 😢 lost confidence in...
# 3597                                          I can't believe the captain on the plane has to tell people that they are allowed to take their mask off if the plane loses pressure in favour of oxygen masks.
# 3645                                                     When I got on my final plane just now the French flight attendant gave me one of those blue surgical masks because my cloth mask "did not look good"
# 3658  Today, someone called me ma'am on the plane. Lol, that's like the second time someone has called me that. My own gf says I look feminine. C'mon, man. I get it though. Nowadays you can't tell. It's...
# 3850  @leggotribe Need a negative Covid test to fly &amp; you must wear a mask on the plane the entire time. Mask mandate anytime you’re inside any where. Also you must provide a negative Covid test if ...
# 3854  @EGYPTAIR @EgyptAir_Online Thanks for replying. This is what bothered me…that most passengers take off their masks..and the cabin does not enforce the rule. The cabin crew themselves are not weari...
# 3919                                 PSA: No one wants to be a mask police. On a plane. On a federal policy that’s been in place for a year and a half. Wear your damn mask or don’t fly, you won’t be missed
# 4010                                                                                                                 They stopped the plane for his dumbass to read the brochure about him wearing the mask 😷
# 4011                                                                                                          Guy on a @Delta plane is refusing to wear his mask properly. What an entire white piece of shit
# 4015                                                                                        Dude on plane wearing his mask halfway down. I want to ask him to cover up, but then, what if he flips out on me?
# 4072                                  When you find yourself on a plane and there is more coughing than you’ve heard for the past 18 months…you make sure your double mask is secure. https://t.co/lcXN4fG8tN
#
#                                                                                                                   geo  \
# 12                                                                                   {'place_id': '7142eb97ae21e839'}
# 17    {'place_id': 'ac88a4f17a51c7fc', 'coordinates': {'type': 'Point', 'coordinates': [-122.59622222, 45.58886979]}}
# 29     {'place_id': '00c39537733fa112', 'coordinates': {'type': 'Point', 'coordinates': [-73.87288343, 40.77195338]}}
# 40                                                                                   {'place_id': '019e0ca71523f3f0'}
# 93                                                                                   {'place_id': '0fc7e0a406d55000'}
# 127                                                                                  {'place_id': 'b39bbbbd69b97fc0'}
# 191    {'coordinates': {'type': 'Point', 'coordinates': [-84.41978006, 33.63975444]}, 'place_id': '7142eb97ae21e839'}
# 201                                                                                  {'place_id': '30344aecffe6a491'}
# 203                                                                                  {'place_id': '7a863bb88e5bb33c'}
# 211        {'coordinates': {'type': 'Point', 'coordinates': [-90.070864, 29.948479]}, 'place_id': 'dd3b100831dd1763'}
# 212   {'coordinates': {'type': 'Point', 'coordinates': [-115.14609442, 36.08193045]}, 'place_id': '8fa6d7a33b83ef26'}
# 221                                                                                  {'place_id': '101f6c4cf696e007'}
# 270                                                                                  {'place_id': '43d2418301bf1a49'}
# 286                                                                                  {'place_id': 'b463d3bd6064861b'}
# 291            {'coordinates': {'type': 'Point', 'coordinates': [-93.7501, 32.5141]}, 'place_id': '4ec71fc3f2579572'}
# 296                                                                                  {'place_id': '7142eb97ae21e839'}
# 373                                                                                  {'place_id': 'bd7c511e9f8bc5da'}
# 458                                                                                  {'place_id': 'e21c8e4914eef2b3'}
# 718                                                                                  {'place_id': 'dea1eac2d7ef8878'}
# 881                                                                                  {'place_id': '1d9a5370a355ab0c'}
# 959                                                                                  {'place_id': '750b50f961913ce0'}
# 1140                                                                                 {'place_id': '56909099a1d44057'}
# 1460                                                                                 {'place_id': '4de072969805ac41'}
# 1600                                                                                 {'place_id': 'ac31053cb03c56b2'}
# 1727                                                                                 {'place_id': '1d9a5370a355ab0c'}
# 1789                                                                                 {'place_id': '00c39537733fa112'}
# 1920                                                                                 {'place_id': '1b210235050e5e85'}
# 2012                                                                                 {'place_id': '1d9a5370a355ab0c'}
# 2297                                                                                 {'place_id': 'fbd6d2f5a4e4a15e'}
# 2361                                                                                 {'place_id': 'e68b57affea10f1d'}
# 2446                                                                                 {'place_id': '00ab941b685334e3'}
# 2510                                                                                 {'place_id': '0073b76548e5984f'}
# 2641                                                                                 {'place_id': '013b5456649606dc'}
# 2750                                                                                 {'place_id': '1ff3790a528c2f97'}
# 2950                                                                                 {'place_id': '4704ec88fc4e529a'}
# 3063                                                                                 {'place_id': '1e5cb4d0509db554'}
# 3095                                                                                 {'place_id': 'f995a9bd45d4a867'}
# 3225                                                                                 {'place_id': '55b4f9e5c516e0b6'}
# 3236                                                                                 {'place_id': '011add077f4d2da3'}
# 3262                                                                                 {'place_id': '0fc34370f9955007'}
# 3322                                                                                 {'place_id': '09f6a7707f18e0b1'}
# 3425                                                                                 {'place_id': 'dd9c503d6c35364b'}
# 3479                                                                                 {'place_id': '018929347840059e'}
# 3510                                                                                 {'place_id': '869128921e17bb3c'}
# 3556                                                                                 {'place_id': '07c18bed48c5d94f'}
# 3597                                                                                 {'place_id': '55485f68a3057620'}
# 3645                                                                                 {'place_id': '07185ea0ed96fe09'}
# 3658                                                                                 {'place_id': '8fa6d7a33b83ef26'}
# 3850                                                                                 {'place_id': '00eb8de9015a3185'}
# 3854                                                                                 {'place_id': '99cdab25eddd6bce'}
# 3919                                                                                 {'place_id': '3d533362cdab8107'}
# 4010                                                                                 {'place_id': '512a8a4a4c4b4be0'}
# 4011                                                                                 {'place_id': '512a8a4a4c4b4be0'}
# 4015                                                                                 {'place_id': '00ab941b685334e3'}
# 4072                                                                                 {'place_id': '0fc8ef8e7c55e000'}
#
#                        Created
# 12   2021-09-09 13:31:38+00:00
# 17   2021-09-09 11:46:02+00:00
# 29   2021-09-09 03:41:01+00:00
# 40   2021-09-08 18:14:29+00:00
# 93   2021-09-08 00:06:08+00:00
# 127  2021-09-07 16:35:57+00:00
# 191  2021-09-06 19:48:14+00:00
# 201  2021-09-06 17:19:07+00:00
# 203  2021-09-06 16:22:24+00:00
# 211  2021-09-06 01:55:57+00:00
# 212  2021-09-05 23:36:10+00:00
# 221  2021-09-05 18:57:42+00:00
# 270  2021-09-04 18:16:31+00:00
# 286  2021-09-04 15:30:07+00:00
# 291  2021-09-04 12:19:21+00:00
# 296  2021-09-04 10:39:57+00:00
# 373  2021-09-03 05:25:28+00:00
# 458  2021-09-09 13:53:05+00:00
# 718  2021-09-07 15:01:13+00:00
# 881  2021-09-09 16:00:51+00:00
# 959  2021-09-06 20:21:15+00:00
# 1140 2021-09-05 22:57:33+00:00
# 1460 2021-09-03 20:16:56+00:00
# 1600 2021-09-03 14:05:11+00:00
# 1727 2021-09-03 15:16:56+00:00
# 1789 2021-09-03 13:23:31+00:00
# 1920 2021-09-03 03:17:39+00:00
# 2012 2021-09-03 00:04:15+00:00
# 2297 2021-09-09 15:15:27+00:00
# 2361 2021-09-09 14:07:57+00:00
# 2446 2021-09-09 11:37:01+00:00
# 2510 2021-09-09 05:10:25+00:00
# 2641 2021-09-09 01:12:37+00:00
# 2750 2021-09-08 21:11:20+00:00
# 2950 2021-09-08 17:25:39+00:00
# 3063 2021-09-08 12:27:16+00:00
# 3095 2021-09-08 06:33:15+00:00
# 3225 2021-09-07 18:38:21+00:00
# 3236 2021-09-07 17:57:54+00:00
# 3262 2021-09-07 16:30:31+00:00
# 3322 2021-09-07 11:33:12+00:00
# 3425 2021-09-06 19:12:48+00:00
# 3479 2021-09-06 11:06:25+00:00
# 3510 2021-09-06 02:49:53+00:00
# 3556 2021-09-05 21:00:44+00:00
# 3597 2021-09-05 16:04:30+00:00
# 3645 2021-09-05 07:49:11+00:00
# 3658 2021-09-05 03:49:34+00:00
# 3850 2021-09-04 14:40:53+00:00
# 3854 2021-09-04 14:22:00+00:00
# 3919 2021-09-04 02:21:05+00:00
# 4010 2021-09-03 15:58:55+00:00
# 4011 2021-09-03 15:58:24+00:00
# 4015 2021-09-03 14:49:52+00:00
# 4072 2021-09-03 02:18:10+00:00

# %% [markdown]
# ### Doesn't seem that geo is all that helpful but since we have filtered on englidh tweets and removed the Raspberry Pi automated tweets now we can shed those columns and begin preprocessing.

# %%
#Running through an API for sentiment analysis

url = "https://text-analysis12.p.rapidapi.com/sentiment-analysis/api/v1.1"

payload = "{\"language\": \"english\", \"text\": \"I want less taxes.\"}"

headers = {
    'content-type': "application/json",
    'x-rapidapi-host': "text-analysis12.p.rapidapi.com",
    'x-rapidapi-key': "f8d244aeb1msha67e6edebf2951dp1304d6jsn215788b5fa29"
    }

response = requests.request("POST", url, data=payload, headers=headers)

print(response.json)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
response.text
# Out:
# '{"time_taken":0.007585048675537109,"msg":"Sentiment Analysis successful","ok":true,"aggregate_sentiment":{"neg":0.0,"neu":0.606,"pos":0.394,"compound":0.0772},"sentiment_list":[{"neg":0.0,"neu":0.606,"pos":0.394,"compound":0.0772,"sentence":"I want less taxes."}],"sentiment":"positive"}'

# %%
new_stopwords = ["sxsw", "android", "google", "apple", "ipad", "app", "austin", 'iphone']
punctuations = string.punctuation
stopwords.extend(new_stopwords)
stopwords.extend(punctuations)
